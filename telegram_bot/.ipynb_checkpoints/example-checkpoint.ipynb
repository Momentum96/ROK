# %%
import telegram

telgm_token = '1338318413:AAFugR-qJ8TpCYBwOf6Y2kAPqdHc56cjeek'

bot = telegram.Bot(token = telgm_token)

# %%
# # 봇에게 메세지 보내서 chat id 알아내기 용 (채팅방 key값)
# updates = bot.getUpdates()

# print(updates)
# for i in updates:
#     print(i)

# %%
# 채팅방에 메세지 보내기
bot.sendMessage(chat_id='1337435696', text='채팅봇 테스트입니다.')
